# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\OLUWAJOBA\.jupyter\fuel_ferc1.csv')
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
len(df)
# Out:
# 29523

# %%
df1=df[df['fuel_type_code_pudl']=='coal']
print(df1)
df.groupby('report_year')
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# 15        f1_fuel_1994_12_6_0_4                 6         1994
# 16        f1_fuel_1994_12_6_0_7                 6         1994
# 17       f1_fuel_1994_12_6_0_10                 6         1994
# 18       f1_fuel_1994_12_6_0_13                 6         1994
# ...

# %%
df['fuel_cost_per_unit_burned'].describe()
# Out:
# count     29523.000000
# mean        208.649031
# std        2854.490090
# min        -276.080000
# 25%           5.207000
# 50%          26.000000
# 75%          47.113000
# max      139358.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
df1.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    475
# 1995    475
# 1996    431
# 1997    417
# 1998    431
# 1999    425
# 2000    403
# 2001    363
# 2002    332
# 2003    329
# 2004    322
# 2005    324
# 2006    327
# 2007    330
# 2008    322
# 2009    319
# 2010    316
# 2011    323
# 2012    327
# 2013    320
# 2014    295
# 2015    268
# 2016    239
# 2017    223
# 2018    211
# Name: report_year, dtype: int64

# %%
df.dropna()
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
df.isnull().any()
# Out:
# record_id                       False
# utility_id_ferc1                False
# report_year                     False
# plant_name_ferc1                False
# fuel_type_code_pudl             False
# fuel_unit                        True
# fuel_qty_burned                 False
# fuel_mmbtu_per_unit             False
# fuel_cost_per_unit_burned       False
# fuel_cost_per_unit_delivered    False
# fuel_cost_per_mmbtu             False
# dtype: bool

# %%
#chech for duplicate rows
df.duplicated().any()
# Out:
# False

# %%
df['fuel_cost_per_unit_burned'].value_counts()
# Out:
# 0.000      288
# 3.050       20
# 2.210       18
# 3.380       18
# 3.560       18
# 4.400       17
# 3.020       16
# 2.450       16
# 3.350       16
# 2.710       16
# 2.610       16
# 2.600       15
# 3.300       15
# 4.420       15
# 3.550       15
# 4.580       15
# 3.440       15
# 2.300       14
# 3.310       14
# 2.750       14
# 2.330       14
# 2.780       14
# 3.360       14
# 3.170       14
# 3.070       14
# 2.640       14
# 3.270       14
# 2.890       14
# 3.040       13
# 2.770       13
#           ...
# 7.380        1
# 46.941       1
# 52.447       1
# 87.700       1
# 49.412       1
# 7.968        1
# 46.735       1
# 75.434       1
# 41.862       1
# 27.866       1
# 3.138        1
# 26.376       1
# 101.760      1
# 104.606      1
# 42.557       1
# 2.796        1
# 89.582       1
# 47.920       1
# 28.697       1
# 36.186       1
# 1.633        1
# 81.450       1
# 1.726        1
# 41.354       1
# 17.008       1
# 8.643        1
# 4.508        1
# ...

# %%
df['fuel_unit'].nunique()
# Out:
# 9

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.groupby('fuel_unit')['fuel_unit'].count()
df.groupby
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
df[['fuel_unit']]=df[['fuel_unit']].fillna(value='mcf')

# %%
df.groupby('report_year')['fuel_cost_per_unit_delivered'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: fuel_cost_per_unit_delivered, dtype: int64

# %%
df.groupby('report_year').first()
df.groupby('fuel_cost_per_unit_burned').first()
# Out:
#                                           record_id  utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.080                    f1_fuel_2000_12_194_3_3               194
# -174.670                    f1_fuel_2000_12_194_3_6               194
# -123.310                   f1_fuel_2000_12_194_2_15               194
# -119.040                    f1_fuel_2003_12_281_1_4               281
# -85.760                     f1_fuel_1995_12_194_5_9               194
# -85.750                    f1_fuel_1995_12_194_5_12               194
# -70.884                      f1_fuel_2011_12_27_1_3                27
# -59.680                     f1_fuel_2002_12_281_1_4               281
# -57.490                    f1_fuel_1994_12_194_5_12               194
# -57.470                    f1_fuel_1994_12_194_5_15               194
# -57.450                     f1_fuel_1994_12_194_5_9               194
# -53.630                     f1_fuel_1995_12_194_4_9               194
# ...

# %%
df1=df.iloc[0:19000].reset_index(drop=True)
df2=df.iloc[19000:].reset_index(drop=True)
pd.merge(df1,df2,how='right')
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_2009_12_79_0_2                79         2009
# 1        f1_fuel_2009_12_79_0_4                79         2009
# 2        f1_fuel_2009_12_79_0_5                79         2009
# 3        f1_fuel_2009_12_79_0_7                79         2009
# 4       f1_fuel_2009_12_79_0_10                79         2009
# 5       f1_fuel_2009_12_79_0_13                79         2009
# 6        f1_fuel_2009_12_79_1_4                79         2009
# 7        f1_fuel_2009_12_79_1_5                79         2009
# 8        f1_fuel_2009_12_79_1_7                79         2009
# 9       f1_fuel_2009_12_79_1_10                79         2009
# 10      f1_fuel_2009_12_79_1_13                79         2009
# 11       f1_fuel_2009_12_79_2_1                79         2009
# 12       f1_fuel_2009_12_79_2_2                79         2009
# 13       f1_fuel_2009_12_79_2_4                79         2009
# ...

# %%
len(df)==len(df1)+len(df2)
# Out:
# True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(7,4))
plt.xticks(rotation=45)
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5,0,'Fuel Unit')

# %%
#Because of the extreme range of the values for the fuel unit, we can plot the barchart by taking the logarithm of the y-axis as follows:

g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5,0,'Fuel Unit')

# %%
import numpy as np
fig=plt.figure(figsize=(7,4))
ax=plt.axes()
plt.plot(df['fuel_type_code_pudl'],df['fuel_cost_per_unit_burned'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8083775f815e> in <module>()
#       2 fig=plt.figure(figsize=(7,4))
#       3 ax=plt.axes()
# ----> 4 plt.plot(df['fuel_type_code_pudl'],df['fuel_cost_per_unit_burned'],type='scatter')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
sns.regplot(x=df['utility_id_ferc1'],y=df['fuel_qty_burned'],fit_reg=False)

# %%
df['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
df['fuel_type_code_pudl'].value_counts()       False
fuel_cost_per_unit_delivered
# Out:
# gas        11486
# coal        8547
# oil         8064
# nuclear      818
# waste        441
# other        167
# Name: fuel_type_code_pudl, dtype: int64

# %%
df.groupby('fuel_cost_per_unit_burned')['fuel_cost_per_unit_burned'].count()
# Out:
# fuel_cost_per_unit_burned
# -276.080       1
# -174.670       1
# -123.310       1
# -119.040       1
# -85.760        1
# -85.750        1
# -70.884        1
# -59.680        1
# -57.490        1
# -57.470        1
# -57.450        1
# -53.630        3
# -45.130        3
# -43.712        1
# -42.679        1
# -41.501        1
# -40.536        1
# -39.675        1
# -38.966        1
# -37.809        1
# -35.100        1
# -34.858        1
# -33.014        1
# -31.501        1
# -30.032        1
# -24.295        1
# -7.700         3
# -7.503         1
# -7.390         1
# -3.946         1
#               ..
#  48007.000     1
#  48164.000     1
#  49650.832     1
#  51112.004     1
#  51417.892     3
#  51698.000     1
#  52041.000     1
#  52389.469     1
#  53245.000     1
#  53840.568     1
#  53889.540     3
#  54376.000     1
#  55098.539     3
#  55375.000     1
#  57453.439     1
#  57623.931     3
#  58365.000     1
#  58505.000     1
#  58760.000     1
#  59113.631     1
# ...

# %%
# Import plotting library
import seaborn as sns

# Box plot
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
            palette=["m", "g"], data=df)

# %%
sample_df=df.sample(n=50, random_state=4)
# KDE plot 
sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color="b")
